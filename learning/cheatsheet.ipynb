# %% [markdown]
# # Complex Numbers

# %%
complex = 69
print(complex)
# Out:
# 69

# %%
z = 3 + 4j
print(z.real)
print(z.imag)
# Out:
# 3.0
# 4.0

# %%
a = 3 + 4j
b = 69 + 23j
print(a+b)
print(a-b)
print(a*b)
x = a / b
print(abs(z))
# Out:
# (72+27j)
# (-66-19j)
# (115+345j)
# 5.0

# %%
import cmath

print(cmath.sqrt(b))
type(3 + 4j)
# Out:
# (8.41820604950582+1.3660867805291002j)
# complex

# %% [markdown]
# # List, Set, Tuple, Range, Dictionary

# %%
my_list = [39, 49, 59]
print(my_list)
my_list.append(69)
print(my_list)
# Out:
# [39, 49, 59]
# [39, 49, 59, 69]

# %%
print(list(range(10, 0, -2)))
# Out:
# [10, 8, 6, 4, 2]

# %%
person = {
    "name":"MQ",
    "age": 25,
    "balance": 69000000
}

print(person)

print(f" {person["name"]} is just {person["age"]} and he already earns {person["balance"]} every day!")

print
# Out:
# {'name': 'MQ', 'age': 25, 'balance': 69000000}
#  MQ is just 25 and he already earns 69000000 every day!
